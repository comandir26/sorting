# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
sizes = [1000,2000,3000,5000,10000,25000, 50000, 100000]

# %%
comparisons1 = [335076, 1362310, 3023390, 8397190, 33513100, 209718000, 838843000, 3389200000]
copies1 = [6777, 15039, 22454, 36955, 87580, 229645, 474061, 988810]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons1, color = "green")
plt.plot(sizes, copies1, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("QuickSort.Random")
# Out:
# Text(0.5, 1.0, 'QuickSort.Random')

# %%
comparisons2 = [499500, 1999000, 4498500, 12497500, 49995000, 312487500, 1249975000, 4999950000]
copies2 = [999, 1999, 2999, 4999, 9999, 24999, 49999, 99999]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons2, color = "green")
plt.plot(sizes, copies2, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("QuickSort.Sorted")
# Out:
# Text(0.5, 1.0, 'QuickSort.Sorted')

# %%
comparisons3 = [749000, 2998000, 6747000, 18745000, 74990000, 468725000, 1874950000,  7499900000]
copies3 = [250999, 1001999, 2252999, 6254999, 25009999, 156274999, 625049999, 2500099999]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons3, color = "green")
plt.plot(sizes, copies3, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("QuickSort.RevSorted")
# Out:
# Text(0.5, 1.0, 'QuickSort.RevSorted')

# %%
comparisons4 = [499500, 1.999e+06, 4.4985e+06, 1.24975e+07, 4.9995e+07, 3.12488e+08, 1.24998e+09, 4.99995e+09]
copies4 = [248498, 992114, 2.24841e+06, 6.27397e+06, 2.49609e+07, 1.56201e+08, 6.24666e+08, 2.49819e+09]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons4, color = "green")
plt.plot(sizes, copies4, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("BubbleSort.Random")
# Out:
# Text(0.5, 1.0, 'BubbleSort.Random')

# %%
comparisons5 = [499500, 1.999e+06, 4.4985e+06, 1.24975e+07, 4.9995e+07, 3.12488e+08, 1.24998e+09, 4.99995e+09]
copies5 = [0, 0, 0, 0, 0, 0, 0, 0]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons5, color = "green")
plt.plot(sizes, copies5, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("BubbleSort.Sorted")
# Out:
# Text(0.5, 1.0, 'BubbleSort.Sorted')

# %%
comparisons6 = [499500, 1.999e+06, 4.4985e+06, 1.24975e+07, 4.9995e+07, 3.12488e+08, 1.24998e+09, 4.99995e+09]
copies6 = [499500, 1.999e+06, 4.4985e+06, 1.24975e+07, 4.9995e+07, 3.12488e+08, 1.24998e+09, 4.99995e+09]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons6, color = "green")
plt.plot(sizes, copies6, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("BubbleSort.RevSorted")
# Out:
# Text(0.5, 1.0, 'BubbleSort.RevSorted')

# %%
comparisons7 = [16829, 37730, 60242, 107668, 235369, 654816, 1409820, 3019540]
copies7 = [9080, 20154, 32084, 57109, 124176, 343644, 737525, 1574830]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons7, color = "green")
plt.plot(sizes, copies7, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("Pyramidal.Random")
# Out:
# Text(0.5, 1.0, 'Pyramidal.Random')

# %%
comparisons8 = [17583, 39159, 62875, 112126, 244460, 677688, 1455438, 3112517]
copies8 = [9709, 21301, 34253, 60933, 131957, 361455, 773305, 1650855]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons8, color = "green")
plt.plot(sizes, copies8, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("Pyramidal.Sorted")
# Out:
# Text(0.5, 1.0, 'Pyramidal.Sorted')

# %%
comparisons9 = [15965, 35964, 57537, 103227, 226682, 633719, 1366047, 2926640]
copies9 = [8317, 18709, 29751, 53437, 116697, 326587, 698893, 1497435]
plt.figure(figsize=(10,5))
plt.plot(sizes, comparisons9, color = "green")
plt.plot(sizes, copies9, color = "red")
plt.legend(["Comparisons", "Copies"])
plt.title("Pyramidal.RevSorted")
# Out:
# Text(0.5, 1.0, 'Pyramidal.RevSorted')
